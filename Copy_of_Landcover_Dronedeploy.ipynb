# %% [markdown]
# <a href="https://colab.research.google.com/github/NavyaGRao/dd-ml-segmentation-benchmark/blob/master/Copy_of_Landcover_Dronedeploy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/jamilruet13/dd-ml-segmentation-benchmark.git
# Out:
# Cloning into 'dd-ml-segmentation-benchmark'...
# remote: Enumerating objects: 21, done.
# remote: Counting objects: 100% (21/21), done.
# remote: Compressing objects: 100% (18/18), done.
# remote: Total 261 (delta 8), reused 9 (delta 3), pack-reused 240
# Receiving objects: 100% (261/261), 13.73 MiB | 6.20 MiB/s, done.
# Resolving deltas: 100% (155/155), done.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
cd /content/drive/Shared drives/MM 805/dd-ml-segmentation-benchmark/
# Out:
# /content/drive/Shared drives/MM 805/dd-ml-segmentation-benchmark

# %%
ls
# Out:
# combine.py             libs/            model.h5              README.md
# dataset-medium/        Main_cluster.py  model-resnet18.h5     requirements.txt
# dataset-medium.tar.gz  main_fastai.py   models/               test.py
# dataset-sample/        main_keras1.py   model-vgg16.h5        wandb/
# dataset-sample.tar.gz  main_keras.py    predictions/
# eval.py                Main.py          predictions_cluster/
# img/                   model_15000.h5   __pycache__/

# %%
# !pip3 install -r requirements.txt
# Out:
# ...
#      |████████████████████████████████| 20.4MB 1.6MB/s
# ...
#      |████████████████████████████████| 25.0MB 101kB/s
# ...
#      |████████████████████████████████| 421.8MB 32kB/s
# ...
#      |████████████████████████████████| 1.4MB 36.8MB/s
# ...
#      |████████████████████████████████| 450kB 37.9MB/s
# ...
#      |████████████████████████████████| 3.9MB 36.4MB/s
# ...
#      |████████████████████████████████| 112kB 44.9MB/s
# ...
#      |████████████████████████████████| 102kB 10.7MB/s
# ...
#      |████████████████████████████████| 102kB 11.6MB/s
# ...
#      |████████████████████████████████| 460kB 38.2MB/s
# ...
#      |████████████████████████████████| 71kB 8.7MB/s
# ...
#      |████████████████████████████████| 71kB 8.7MB/s
# ...
#   Created wheel for gast: filename=gast-0.2.2-cp36-none-any.whl size=7540 sha256=c0c22b4c012d55d0763b7eaf9118dd617bffb5d392ee58598bf44469a173a4e8
#   Stored in directory: /root/.cache/pip/wheels/5c/2e/7e/a1d4d4fcebe6c381f378ce7743a3ced3699feb89bcfbdadadd
# ...

# %% [markdown]
# # New Section

# %%
# !wandb login
# Out:
# wandb: You can find your API key in your browser here: https://app.wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter: 1b3e4ed4696608ec287a4a13855d11d4b07482ac
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# Successfully logged in to Weights & Biases!

# %%
# !python3 test.py
# Out:
# 2020-04-27 07:21:11.294443: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libnvinfer.so.6'; dlerror: libnvinfer.so.6: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2020-04-27 07:21:11.294541: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libnvinfer_plugin.so.6'; dlerror: libnvinfer_plugin.so.6: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2020-04-27 07:21:11.294558: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:30] Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# Using TensorFlow backend.
# 2020-04-27 07:21:13.148952: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# ...

# %%
# !python3 main_keras.py
# Out:
# Using TensorFlow backend.
# 2020-04-27 20:01:40.494544: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libnvinfer.so.6'; dlerror: libnvinfer.so.6: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2020-04-27 20:01:40.494717: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libnvinfer_plugin.so.6'; dlerror: libnvinfer_plugin.so.6: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2020-04-27 20:01:40.494745: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:30] Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# wandb: Tracking run with wandb version 0.8.33
# wandb: Run data is saved locally in wandb/run-20200427_200142-3usv69bd
# wandb: Syncing run vague-night-44
# ...

# %%
# !pip3 install keras==
# Out:
# <bound method Network.summary of <tensorflow.python.keras.engine.training.Model object at 0x7f5b85e06c88>>

# %%
import tensorflow as tf
from tensorflow.keras import models

model = models.load_model('model.h5', custom_objects={'tf': tf}, compile= False)
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, 300, 300, 3) 0
# __________________________________________________________________________________________________
# bn_data (BatchNormalization)    (None, 300, 300, 3)  9           input_1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_1 (ZeroPadding2D (None, 306, 306, 3)  0           bn_data[0][0]
# __________________________________________________________________________________________________
# conv0 (Conv2D)                  (None, 150, 150, 64) 9408        zero_padding2d_1[0][0]
# __________________________________________________________________________________________________
# bn0 (BatchNormalization)        (None, 150, 150, 64) 256         conv0[0][0]
# ...

# %%
from libs import inference_keras
import wandb
dataset = 'dataset-sample'
config = {
        'name' : 'baseline-keras',
        'dataset' : dataset,
    }

wandb.init(config=config)
inference_keras.run_inference(dataset, model=model, basedir=wandb.run.dir)
# Out:
#                 Logging results to <a href="https://wandb.com" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://app.wandb.ai/navya/dd-ml-segmentation-benchmark" target="_blank">https://app.wandb.ai/navya/dd-ml-segmentation-benchmark</a><br/>
#                 Run page: <a href="https://app.wandb.ai/navya/dd-ml-segmentation-benchmark/runs/2o04eee2" target="_blank">https://app.wandb.ai/navya/dd-ml-segmentation-benchmark/runs/2o04eee2</a><br/>
# running inference on image dataset-sample/images/1d4fbe33f3_F1BE1D4184INSPIRE-ortho.tif.
# 190/190 [==============================] - 6s 34ms/sample
# running inference on image dataset-sample/images/ec09336a6f_06BA0AF311OPENPIPELINE-ortho.tif.
# 327/327 [==============================] - 4s 11ms/sample
# running inference on image dataset-sample/images/e1d3e6f6ba_B4DE0FB544INSPIRE-ortho.tif.
# ...

# %%
from libs import scoring
score, _ = scoring.score_predictions(dataset, basedir=wandb.run.dir)
print(score)
# Out:
# precision=0.7828566037624116 recall=0.7286784959352384 f1=0.7348883405102996
# {'f1_mean': 0.7348883405102996, 'f1_std': 0.0, 'pr_mean': 0.7828566037624116, 'pr_std': 0.0, 're_mean': 0.7286784959352384, 're_std': 0.0}
